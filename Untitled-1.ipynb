# %%
print("hi")
# Out:
# hi

# %%
# !pip install pandas
# Out:
# ^C
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.6 MB 6.3 MB/s eta 0:00:02
#    - -------------------------------------- 0.5/11.6 MB 7.3 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.6 MB 8.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.4/11.6 MB 8.7 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/11.6 MB 9.3 MB/s eta 0:00:02
#    ------- -------------------------------- 2.3/11.6 MB 9.7 MB/s eta 0:00:01
#    --------- ------------------------------ 2.7/11.6 MB 10.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.1/11.6 MB 10.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.5/11.6 MB 10.1 MB/s eta 0:00:01
# ...

# %%
print("hi")
# Out:
# hi

# %%
import requests


url = "https://62020c66b8735d00174cb6e4.mockapi.io/getListOfSKU"

headers = {}


payload = {}

output = requests.get(url,headers=headers)


if output.status_code == 200:
    print("all okay",output.json())

    final_output = output.json()
# Out:
# all okay [{'sku': '7CT 18CT VP BOLD', 'sap_code': '1009538601000'}, {'name': '8CT 18CT FLAMIN HOT', 'id': '1009538801000'}, {'name': '7CT 18CT VP DR & CT', 'id': '1009637001000'}, {'name': '4CT 28CT VP CLASSIC', 'id': '1009830201000'}, {'name': '8CT 18CT CHEESY', 'id': '1009831701000'}, {'name': '8CT 18CT FLAVOR MIX', 'id': '1009978201000'}, {'name': '3CT 42CT CLS MEGA CUBE', 'id': '1010196801000'}, {'name': '3CT 42CT FLV MEGA MIX', 'id': '1010197601000'}]

# %%
name ={}

for i in final_output:
    if i['name'] == '8CT 18CT FLAMIN HOT':
        print(i["value"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 4
#       1 name ={}
#       3 for i in final_output:
# ----> 4     if i['name'] == '8CT 18CT FLAMIN HOT':
#       5         print(i["value"])
#
# KeyError: 'name'

# %%
count = 0

for item in final_output:
    if 'name' in item: 
        print(item['name']) 
    elif 'sku' in item:
        print(item['sku']) 

        # Only consider dictionaries that have a 'name' key
        # count += 1
        # if count == 2:  # Stop at the second occurrence
        #     print(item['name'])
        #     break
# Out:
# 7CT 18CT VP BOLD
# 8CT 18CT FLAMIN HOT
# 7CT 18CT VP DR & CT
# 4CT 28CT VP CLASSIC
# 8CT 18CT CHEESY
# 8CT 18CT FLAVOR MIX
# 3CT 42CT CLS MEGA CUBE
# 3CT 42CT FLV MEGA MIX
